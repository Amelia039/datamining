# %% [markdown]
# # Tugas 2

# %%
#import library
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import statistics as st
from scipy import stats

url="https://raw.githubusercontent.com/Amelia039/my-dataset/main/IRIS.csv"

c=pd.read_csv(url)
c
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
labels = ["Kategori1", "Kategori2 ", "Kategori3"]
binning = pd.cut(c['petal_length'],3).value_counts()

binning
# Out:
# (2.967, 4.933]    54
# (0.994, 2.967]    50
# (4.933, 6.9]      46
# Name: petal_length, dtype: int64

# %%
labels = ["Kategori1", "Kategori2 ", "Kategori3"]
binning = pd.cut(c['petal_length'],3,labels=labels).value_counts()

binning
# Out:
# Kategori2     54
# Kategori1     50
# Kategori3     46
# Name: petal_length, dtype: int64
